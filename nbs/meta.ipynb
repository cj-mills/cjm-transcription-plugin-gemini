# %% [markdown]
# # Metadata
#
# > Metadata introspection for the Gemini plugin used by cjm-ctl to generate the registration manifest.

# %%
#| default_exp meta

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
import os
import sys
from typing import Any, Dict
from cjm_transcription_plugin_gemini import __version__

# %%
#| export
def get_plugin_metadata() -> Dict[str, Any]: # Plugin metadata for manifest generation
    """Return metadata required to register this plugin with the PluginManager."""
    # Fallback base path (current behavior for backward compatibility)
    base_path = os.path.dirname(os.path.dirname(sys.executable))
    
    # Use CJM config if available, else fallback to env-relative paths
    cjm_data_dir = os.environ.get("CJM_DATA_DIR")
    
    # Plugin data directory
    plugin_name = "cjm-transcription-plugin-gemini"
    if cjm_data_dir:
        data_dir = os.path.join(cjm_data_dir, plugin_name)
    else:
        data_dir = os.path.join(base_path, "data")
    
    db_path = os.path.join(data_dir, "gemini_transcriptions.db")
    
    # Ensure data directory exists
    os.makedirs(data_dir, exist_ok=True)

    return {
        "name": plugin_name,
        "version": __version__,
        "type": "transcription",
        "category": "transcription",
        "interface": "cjm_transcription_plugin_system.plugin_interface.TranscriptionPlugin",
        
        "module": "cjm_transcription_plugin_gemini.plugin",
        "class": "GeminiPlugin",
        
        # Critical: The absolute path to THIS environment's python
        "python_path": sys.executable,
        
        "db_path": db_path,
        
        # Gemini is an API wrapper - lightweight requirements
        "resources": {
            "requires_gpu": False,
            "min_gpu_vram_mb": 0,
            "recommended_gpu_vram_mb": 0,
            "min_system_ram_mb": 512
        },
        
        "env_vars": {
            # API key should be set in environment or config
            # "GEMINI_API_KEY": "" - intentionally not set here
        }
    }

# %% [markdown]
# ## Testing

# %%
import json

metadata = get_plugin_metadata()
print(json.dumps(metadata, indent=2))
# Out:
# {
#   "name": "cjm-transcription-plugin-gemini",
#   "version": "0.0.11",
#   "type": "transcription",
#   "category": "transcription",
#   "interface": "cjm_transcription_plugin_system.plugin_interface.TranscriptionPlugin",
#   "module": "cjm_transcription_plugin_gemini.plugin",
#   "class": "GeminiPlugin",
#   "python_path": "/home/innom-dt/miniforge3/envs/cjm-transcription-plugin-gemini/bin/python3.11",
#   "db_path": "/home/innom-dt/miniforge3/envs/cjm-transcription-plugin-gemini/data/gemini_transcriptions.db",
#   "resources": {
#     "requires_gpu": false,
#     "min_gpu_vram_mb": 0,
#     "recommended_gpu_vram_mb": 0,
#     "min_system_ram_mb": 512
#   },
#   "env_vars": {}
# }

# %%
#| hide
import nbdev; nbdev.nbdev_export()
